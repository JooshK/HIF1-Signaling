# %%
import basico
import numpy as np 
import matplotlib.pyplot as plt

# %%
model = basico.load_model("../../data/Nguyen2013_HIF.cps")

# %%
basico.get_species()
# Out:
#                   compartment       type    unit  initial_concentration  \
# name
# HIFalpha              Cytosol  reactions  nmol/l                    5.0
# HIFalpha-pOH          Cytosol  reactions  nmol/l                    0.0
# VHL                   Cytosol  reactions  nmol/l                   50.0
# FIH                   Cytosol  reactions  nmol/l                  110.0
# HIFalpha-aOH          Cytosol  reactions  nmol/l                    0.0
# PHD                   Cytosol  reactions  nmol/l                  100.0
# HIFalpha-aOHpOH       Cytosol  reactions  nmol/l                    0.0
# O2                    Cytosol  reactions  nmol/l                  100.0
# HIFalpha_n            Nucleus  reactions  nmol/l                    0.0
# PHD_n                 Nucleus  reactions  nmol/l                    0.0
# HIFalpha_n-pOH        Nucleus  reactions  nmol/l                    0.0
# VHL_n                 Nucleus  reactions  nmol/l                   50.0
# ...

# %%
basico.get_compartments()
# Out:
#           type unit  initial_size initial_expression  dimensionality  \
# name
# Cytosol  fixed    l           1.0                                  3
# Nucleus  fixed    l           1.0                                  3
#
#         expression  size  rate            key sbml_id
# name
# Cytosol              1.0   0.0  Compartment_0
# Nucleus              1.0   0.0  Compartment_1

# %%
tc = basico.run_time_course(duration = 100)
tc.head()
# Out:
#       HIFalpha  HIFalpha_n  HIFalpha-aOH         PHD  HIFalpha_n-aOH  \
# Time
# 0.0   5.000000    0.000000      0.000000  100.000000        0.000000
# 1.0   1.817722    0.002392      3.142077   99.989001        0.001014
# 2.0   0.603570    0.002272      4.341915   99.978004        0.002802
# 3.0   0.196561    0.001646      4.744181   99.967010        0.004541
# 4.0   0.067113    0.001089      4.872048   99.956018        0.006070
#
#               mRNA       Protein  HIFd_HRE  HIFalpha-pOH  HIFalpha_n-pOH  \
# Time
# 0.0   0.000000e+00  0.000000e+00  0.000000      0.000000    0.000000e+00
# 1.0   1.050278e-09  1.980376e-12  0.000002      0.038767    1.236090e-09
# 2.0   1.265655e-08  4.982395e-11  0.000014      0.051271    5.786105e-09
# 3.0   4.912581e-08  3.014938e-10  0.000033      0.054141    1.174234e-08
# 4.0   1.211794e-07  1.026061e-09  0.000058      0.053873    1.728901e-08
#
#       HIFalpha-aOHpOH  HIFalpha_n-aOHpOH      HIFd     PHD_n    Luciferase  \
# Time
# ...
